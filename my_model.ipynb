# %% [markdown]
# <a href="https://colab.research.google.com/github/kalondepeace/kalondepeace/blob/main/my_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
my_layer = keras.layers.Dense(units=1 , input_shape= [1])
model = tf.keras.Sequential([my_layer])
model.compile(optimizer='sgd' , loss='mean_squared_error')

xs = np.array([1.0,3.1,2.4,2.3],dtype=float)
ys = np.array([2.1,3.2,4.5,6.7],dtype=float)
model.fit(xs, ys, epochs=500 )
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 580ms/step - loss: 49.1424
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 38.1346
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 29.7351
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 23.3259
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 18.4353
# Epoch 6/500
# 1/1 [==============================] - 0s 15ms/step - loss: 14.7034
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 11.8558
# Epoch 8/500
# 1/1 [==============================] - 0s 12ms/step - loss: 9.6828
# Epoch 9/500
# 1/1 [==============================] - 0s 12ms/step - loss: 8.0246
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7592
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.7935
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0565
# ...

# %%
print(model.predict([10.0]))
print(my_layer.get_weights())
# Out:
# 1/1 [==============================] - 0s 35ms/step
# [[12.2384205]]
# [array([[1.0460184]], dtype=float32), array([1.7782369], dtype=float32)]
